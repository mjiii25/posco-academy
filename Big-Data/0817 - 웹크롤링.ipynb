# %% [markdown]
# # 0817 - 웹크롤링
#
# - 요청 request
# - selenium
# - 응답 response

# %% [markdown]
# **selenium 사용하기**

# %%
from selenium import webdriver

driver = webdriver.Chrome('chromedriver')

# %%
url = "https://comic.naver.com/index"
driver.get(url)

# %%
for i in range(1,11):
    i = format(i, "02")
    selector = "#realTimeRankFavorite > li.rank{} > a".format(i)
    title = driver.find_element_by_css_selector(selector)
    print(i, "위", title.text)

# %%
selector = "#main_contents > ul > li:nth-child(6) > div.detail > div.title > a > strong"
title = driver.find_element_by_css_selector(selector)
title.text

# %%
url = "http://www.kyobobook.co.kr/bestSellerNew/bestseller.laf?orderClick=d79"
driver.get(url)

# %% [markdown]
# **BeautifulSoup 사용**

# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
html_src = driver.page_source

soup = BeautifulSoup(html_src, 'html.parser')
soup

# %%
selector = "#main_contents > ul > li:nth-child(6) > div.detail > div.title > a > strong"
soup.select(selector).text

# %% [markdown]
# <html>                         - head, body의 부모
#     <head>...</head>           - html의 자식
#         <title>...</title>     - head의 자식, html의 손자
#     <body>...</body>           - html의 자식
# </html>

# %%
selector = 'body > div > div'     # div 안의 div 찾아라
title = driver.find_element_by_css_selector(selector)
title.text

<body>
    <div>
        <div>...</div>
        <strong>,,,</strong>
        <a href = "...">...</a>
        <p>...</p>
    </div>
</body>

# %% [markdown]
# **네이버 '철강용어사전'의 표제어 제목 출력하기**

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('chromedriver')

# %%
url = "https://terms.naver.com/list.naver?cid=67995&categoryId=67995"
driver.get(url)

# %%
#content > div.list_wrap > ul > li:nth-child(1) > div > div.subject > strong > a:nth-child(1)
#content > div.list_wrap > ul > li:nth-child(2) > div > div.subject > strong > a:nth-child(1)
#content > div.list_wrap > ul > li:nth-child(3) > div.info_area > div.subject > strong > a:nth-child(1)
#content > div.list_wrap > ul > li:nth-child(4) > div.info_area > div.subject > strong > a:nth-child(1)
#content > div.list_wrap > ul > li:nth-child(5) > div.info_area > div.subject > strong > a:nth-child(1)

# %%
for i in range(1,16) :
    selector = "#content > div.list_wrap > ul > li:nth-child({}) > div > div.subject > strong > a:nth-child(1)".format(i)
    title = driver.find_element_by_css_selector(selector)
    print(title.text)

# %%
pgsrc = driver.page_source
soup = BeautifulSoup(pgsrc, 'html.parser')
soup

# %%
titles = soup.select("strong.title > a:nth-child(1)")


for title in titles[1:] :
    print(title.text)

# %% [markdown]
# **Request**

# %%
# !pip install requests

# %%
import requests

# %%
url = "https://www.naver.com"
requests.get(url, verify = )

# %%
url = 
param = 

where : news
sm : tab_jum
query : 아이유

# %%
url = "https://finance.naver.com/item/main.naver?code=005490"

res = requests.get(url, verify = False)
res.text

# %%
import requests

url = "https://www.naver.com"
res = requests.get(url, verify=False)
res.text

# %%
import requests

search_key = "아이유"

url = "https://search.naver.com/search.naver"
p = {"where": "news", "query": search_key}

res = requests.get(url, params=p)
res.text

# %%
url = "https://finance.naver.com/item/main.naver?code=005490"

res = requests.get(url)
res.text

# %%
where: news
sm: tab_jum
query: 아이유

# %%
where: news
sm: tab_pge
query: 아이유
sort: 0
photo: 0
field: 0
pd: 0
cluster_rank: 24
mynews: 0
office_type: 0
office_section_code: 0
nso: so:r,p:all,a:all
start: 11

# %%
url = "https://www.investing.com/commodities/iron-ore-62-cfr-futures"
res = res = requests(url, verify = False)

soup = BeautifulSoup(res.text, 'html.parser')
price = soup.select('.....')
for p in prices : 
    print(p.text)

# %%
url = "https://api.investing.com/api/financialdata/961729/historical/chart/"
p = {"period": "P6M","interval": "P1D","pointscount": "120"}
h = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36"}

res = requests.get(url, params = p, headers=h, verify=False)

iron_info = res.json()

# %%
info_list = []
for info in iron_info['data'] :
    t = info[0]
    p = info[1]
    d = {'시간' : t, '가격' : p}
    info_list.append(d)

# %%
info_list

# %% [markdown]
# **BeautifulSoup 이용하기**

# %%
from bs4 import BeautifulSoup

url = "https://movie.naver.com/movie/bi/mi/basic.naver?code=187310"
res = requests.get(url)

# %%
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <title>미나리 : 네이버 영화</title>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 미나리" property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1">
# <meta content="미나리" property="me2:category2"/>
# <meta content="미나리" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/bi/mi/basic.naver?code=187310" property="og:url"/>
# <meta content="https://movie-phinf.pstatic.net/20210429_50/1619658051996HIPXs_JPEG/movie_image.jpg?type=m665_443_2" property="og:image"/>
# <meta content='"미나리는 어디서든 잘 자라"낯선 미국, 아칸소로 떠나온 한국 가족.가족들에게 뭔가 해내는 ...' property="og:description"/>
# ...

# %%
data_list = soup.select('.list li strong')
for data in data_list :
    print(data.text)

# %%
from selenium import webdriver

driver = webdriver.Chrome('chromedriver')

# %%
url = "https://movie.naver.com/movie/bi/mi/basic.naver?code=187310"
driver.get(url)

# %%
selector = "#content > div.article > div.section_group.section_group_frst > div:nth-child(5) > div:nth-child(2) > div.score_result > ul > li:nth-child(1) > div.score_reple > p"

# %%
import requests
from bs4 import BeautifulSoup

url =  "https://movie.naver.com/movie/bi/mi/basic.naver?code=187310"
res = requests.get(url, verify=False)

soup = BeautifulSoup(res.text, "html.parser")

comments = soup.select("div.score_reple > p")

for comment in comments:
    a = comment.select("a")
    if len(a) > 0:
        print(a[0].attrs["data-src"])
    else:
        print(comment.text.strip())
